# %%
import pandas as pd
import numpy as np

# %%
train=pd.read_csv("C:/Users/sirola/Downloads/PHD/Train-1542865627584.csv")
train_in=pd.read_csv("C:/Users/sirola/Downloads/PHD/Train_Inpatientdata-1542865627584.csv")
train_out=pd.read_csv("C:/Users/sirola/Downloads/PHD/Train_Outpatientdata-1542865627584.csv")
train_ben=pd.read_csv("C:/Users/sirola/Downloads/PHD/Train_Beneficiarydata-1542865627584.csv")

# %%
test=pd.read_csv("C:/Users/sirola/Downloads/PHD/PHD_Test-1542969243754.csv")
test_in=pd.read_csv("C:/Users/sirola/Downloads/PHD/Test_Inpatientdata-1542969243754.csv")
test_out=pd.read_csv("C:/Users/sirola/Downloads/PHD/Test_Outpatientdata-1542969243754.csv")
test_ben=pd.read_csv("C:/Users/sirola/Downloads/PHD/Test_Beneficiarydata-1542969243754.csv")

# %%
train.shape
# Out:
# (5410, 2)

# %%
train_in.shape
# Out:
# (40474, 30)

# %%
train_out.shape
# Out:
# (517737, 27)

# %%
train_ben.shape
# Out:
# (138556, 25)

# %%
test.shape
# Out:
# (1353, 1)

# %%
test_in.shape
# Out:
# (9551, 30)

# %%
test_out.shape
# Out:
# (125841, 27)

# %%
test_ben.shape
# Out:
# (63968, 25)

# %%
train.columns
# Out:
# Index(['Provider', 'PotentialFraud'], dtype='object')

# %%
train_in.columns
# Out:
# Index(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
#        'OtherPhysician', 'AdmissionDt', 'ClmAdmitDiagnosisCode',
#        'DeductibleAmtPaid', 'DischargeDt', 'DiagnosisGroupCode',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
#        'ClmProcedureCode_6'],
#       dtype='object')

# %%
train_out.columns
# Out:
# Index(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
#        'OtherPhysician', 'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2',
#        'ClmDiagnosisCode_3', 'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5',
#        'ClmDiagnosisCode_6', 'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8',
#        'ClmDiagnosisCode_9', 'ClmDiagnosisCode_10', 'ClmProcedureCode_1',
#        'ClmProcedureCode_2', 'ClmProcedureCode_3', 'ClmProcedureCode_4',
#        'ClmProcedureCode_5', 'ClmProcedureCode_6', 'DeductibleAmtPaid',
#        'ClmAdmitDiagnosisCode'],
#       dtype='object')

# %%
train_ben.columns
# Out:
# Index(['BeneID', 'DOB', 'DOD', 'Gender', 'Race', 'RenalDiseaseIndicator',
#        'State', 'County', 'NoOfMonths_PartACov', 'NoOfMonths_PartBCov',
#        'ChronicCond_Alzheimer', 'ChronicCond_Heartfailure',
#        'ChronicCond_KidneyDisease', 'ChronicCond_Cancer',
#        'ChronicCond_ObstrPulmonary', 'ChronicCond_Depression',
#        'ChronicCond_Diabetes', 'ChronicCond_IschemicHeart',
#        'ChronicCond_Osteoporasis', 'ChronicCond_rheumatoidarthritis',
#        'ChronicCond_stroke', 'IPAnnualReimbursementAmt',
#        'IPAnnualDeductibleAmt', 'OPAnnualReimbursementAmt',
#        'OPAnnualDeductibleAmt'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['Provider'], dtype='object')

# %%
test_in.columns
# Out:
# Index(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
#        'OtherPhysician', 'AdmissionDt', 'ClmAdmitDiagnosisCode',
#        'DeductibleAmtPaid', 'DischargeDt', 'DiagnosisGroupCode',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
#        'ClmProcedureCode_6'],
#       dtype='object')

# %%
test_out.columns
# Out:
# Index(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
#        'OtherPhysician', 'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2',
#        'ClmDiagnosisCode_3', 'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5',
#        'ClmDiagnosisCode_6', 'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8',
#        'ClmDiagnosisCode_9', 'ClmDiagnosisCode_10', 'ClmProcedureCode_1',
#        'ClmProcedureCode_2', 'ClmProcedureCode_3', 'ClmProcedureCode_4',
#        'ClmProcedureCode_5', 'ClmProcedureCode_6', 'DeductibleAmtPaid',
#        'ClmAdmitDiagnosisCode'],
#       dtype='object')

# %%
test_ben.columns
# Out:
# Index(['BeneID', 'DOB', 'DOD', 'Gender', 'Race', 'RenalDiseaseIndicator',
#        'State', 'County', 'NoOfMonths_PartACov', 'NoOfMonths_PartBCov',
#        'ChronicCond_Alzheimer', 'ChronicCond_Heartfailure',
#        'ChronicCond_KidneyDisease', 'ChronicCond_Cancer',
#        'ChronicCond_ObstrPulmonary', 'ChronicCond_Depression',
#        'ChronicCond_Diabetes', 'ChronicCond_IschemicHeart',
#        'ChronicCond_Osteoporasis', 'ChronicCond_rheumatoidarthritis',
#        'ChronicCond_stroke', 'IPAnnualReimbursementAmt',
#        'IPAnnualDeductibleAmt', 'OPAnnualReimbursementAmt',
#        'OPAnnualDeductibleAmt'],
#       dtype='object')

# %%
train.head(5)
# Out:
#    Provider PotentialFraud
# 0  PRV51001             No
# 1  PRV51003            Yes
# 2  PRV51004             No
# 3  PRV51005            Yes
# 4  PRV51007             No

# %%
train_in.head(5)
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt        ...         ClmDiagnosisCode_7  \
# 0            NaN  2009-04-12        ...                       2724
# 1            NaN  2009-08-31        ...                        NaN
# ...

# %%
train_out.head(5)
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11002  CLM624349   2009-10-11  2009-10-11  PRV56011
# 1  BENE11003  CLM189947   2009-02-12  2009-02-12  PRV57610
# 2  BENE11003  CLM438021   2009-06-27  2009-06-27  PRV57595
# 3  BENE11004  CLM121801   2009-01-06  2009-01-06  PRV56011
# 4  BENE11004  CLM150998   2009-01-22  2009-01-22  PRV56011
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY326117                NaN
# 1                      80          PHY362868                NaN
# 2                      10          PHY328821                NaN
# 3                      40          PHY334319                NaN
# 4                     200          PHY403831                NaN
#
#   OtherPhysician ClmDiagnosisCode_1          ...           ClmDiagnosisCode_9  \
# 0            NaN              78943          ...                          NaN
# ...

# %%
train_ben.head(5)
# Out:
#       BeneID         DOB  DOD  Gender  Race RenalDiseaseIndicator  State  \
# 0  BENE11001  1943-01-01  NaN       1     1                     0     39
# 1  BENE11002  1936-09-01  NaN       2     1                     0     39
# 2  BENE11003  1936-08-01  NaN       1     1                     0     52
# 3  BENE11004  1922-07-01  NaN       1     1                     0     39
# 4  BENE11005  1935-09-01  NaN       1     1                     0     24
#
#    County  NoOfMonths_PartACov  NoOfMonths_PartBCov          ...            \
# 0     230                   12                   12          ...
# 1     280                   12                   12          ...
# 2     590                   12                   12          ...
# 3     270                   12                   12          ...
# 4     680                   12                   12          ...
#
#    ChronicCond_Depression  ChronicCond_Diabetes  ChronicCond_IschemicHeart  \
# ...

# %%
test.head(5)
# Out:
#    Provider
# 0  PRV51002
# 1  PRV51006
# 2  PRV51009
# 3  PRV51010
# 4  PRV51018

# %%
test_in.head(5)
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11014  CLM67387   2009-09-09  2009-09-16  PRV57070
# 1  BENE11017  CLM31237   2008-12-25  2009-01-08  PRV54750
# 2  BENE11026  CLM78930   2009-12-09  2009-12-13  PRV53758
# 3  BENE11031  CLM56810   2009-06-23  2009-07-06  PRV55825
# 4  BENE11085  CLM34625   2009-01-20  2009-01-31  PRV52338
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                    9000          PHY317786          PHY427017
# 1                   14000          PHY314656          PHY426644
# 2                    2000          PHY349495                NaN
# 3                   16000          PHY429538          PHY371893
# 4                   19000          PHY397161                NaN
#
#   OtherPhysician AdmissionDt        ...         ClmDiagnosisCode_7  \
# 0            NaN  2009-09-09        ...                       5990
# 1            NaN  2008-12-25        ...                       4549
# ...

# %%
test_out.head(5)
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM392397   2009-06-02  2009-06-02  PRV55962
# 1  BENE11001  CLM430760   2009-06-23  2009-06-23  PRV56112
# 2  BENE11007  CLM233081   2009-03-07  2009-03-07  PRV56979
# 3  BENE11007  CLM496381   2009-07-29  2009-07-29  PRV56573
# 4  BENE11007  CLM521391   2009-08-12  2009-08-12  PRV56573
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY347633                NaN
# 1                      30          PHY381777                NaN
# 2                     200          PHY425311                NaN
# 3                      10          PHY393253          PHY347995
# 4                      10          PHY417685                NaN
#
#   OtherPhysician ClmDiagnosisCode_1          ...           ClmDiagnosisCode_9  \
# 0      PHY347633              V5832          ...                          NaN
# ...

# %%
test_ben.head(5)
# Out:
#       BeneID         DOB         DOD  Gender  Race RenalDiseaseIndicator  \
# 0  BENE11001  1943-01-01         NaN       1     1                     0
# 1  BENE11007  1940-09-01  2009-12-01       1     2                     0
# 2  BENE11010  1936-07-01         NaN       2     1                     0
# 3  BENE11011  1914-03-01         NaN       2     2                     0
# 4  BENE11014  1938-04-01         NaN       2     1                     Y
#
#    State  County  NoOfMonths_PartACov  NoOfMonths_PartBCov  \
# 0     39     230                   12                   12
# 1     45     610                   12                   12
# 2     41      30                   12                   12
# 3      1     360                   12                   12
# 4     45     780                   12                   12
#
#            ...            ChronicCond_Depression  ChronicCond_Diabetes  \
# 0          ...                                 1                     1
# ...

# %%
train_df1=pd.merge(train_in,train_out,how="outer")
train_df1
# Out:
#             BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0        BENE11001   CLM46614   2009-04-12  2009-04-18  PRV55912
# 1        BENE11001   CLM66048   2009-08-31  2009-09-02  PRV55907
# 2        BENE11001   CLM68358   2009-09-17  2009-09-20  PRV56046
# 3        BENE11011   CLM38412   2009-02-14  2009-02-22  PRV52405
# 4        BENE11014   CLM63689   2009-08-13  2009-08-30  PRV56614
# 5        BENE11017   CLM70950   2009-10-06  2009-10-12  PRV54986
# 6        BENE11018   CLM32075   2009-01-02  2009-01-07  PRV54090
# 7        BENE11028   CLM62376   2009-08-03  2009-08-07  PRV51148
# 8        BENE11031   CLM62784   2009-08-06  2009-08-09  PRV55839
# 9        BENE11034   CLM31519   2008-12-29  2009-01-05  PRV55215
# 10       BENE11034   CLM57949   2009-07-01  2009-07-09  PRV55193
# 11       BENE11036   CLM70083   2009-09-30  2009-10-07  PRV51145
# 12       BENE11037   CLM65412   2009-08-26  2009-08-29  PRV55846
# ...

# %%
train_df2=pd.merge(train_df1,train_ben)
train_df2
# Out:
#             BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0        BENE11001   CLM46614   2009-04-12  2009-04-18  PRV55912
# 1        BENE11001   CLM66048   2009-08-31  2009-09-02  PRV55907
# 2        BENE11001   CLM68358   2009-09-17  2009-09-20  PRV56046
# 3        BENE11011   CLM38412   2009-02-14  2009-02-22  PRV52405
# 4        BENE11011  CLM144521   2009-01-18  2009-01-18  PRV52314
# 5        BENE11011  CLM347780   2009-05-08  2009-05-08  PRV51012
# 6        BENE11011  CLM507201   2009-08-04  2009-08-04  PRV51063
# 7        BENE11014   CLM63689   2009-08-13  2009-08-30  PRV56614
# 8        BENE11014  CLM523157   2009-08-13  2009-08-13  PRV56835
# 9        BENE11017   CLM70950   2009-10-06  2009-10-12  PRV54986
# 10       BENE11017  CLM110718   2008-12-19  2009-01-03  PRV54786
# 11       BENE11017  CLM170448   2009-02-01  2009-02-01  PRV54786
# 12       BENE11017  CLM198169   2009-02-16  2009-02-16  PRV54761
# ...

# %%
train_df3=pd.merge(train_df2,train)
train_df3
# Out:
#             BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0        BENE11001   CLM46614   2009-04-12  2009-04-18  PRV55912
# 1        BENE16973  CLM565430   2009-09-06  2009-09-06  PRV55912
# 2        BENE17521   CLM34721   2009-01-20  2009-02-01  PRV55912
# 3        BENE21718   CLM72336   2009-10-17  2009-11-04  PRV55912
# 4        BENE22934   CLM73394   2009-10-25  2009-10-29  PRV55912
# 5        BENE24402   CLM32911   2009-01-08  2009-01-12  PRV55912
# 6        BENE25016  CLM372477   2009-05-22  2009-05-22  PRV55912
# 7        BENE28966   CLM56700   2009-06-22  2009-06-25  PRV55912
# 8        BENE29251   CLM42062   2009-03-11  2009-03-19  PRV55912
# 9        BENE31905   CLM37729   2009-02-10  2009-03-03  PRV55912
# 10       BENE31905   CLM49964   2009-05-06  2009-05-09  PRV55912
# 11       BENE31905   CLM77968   2009-12-01  2009-12-05  PRV55912
# 12       BENE31905   CLM80697   2009-12-25  2009-12-28  PRV55912
# ...

# %%
test_df1=pd.merge(test_in,test_out,how="outer")
test_df1
# Out:
#             BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0        BENE11014   CLM67387   2009-09-09  2009-09-16  PRV57070
# 1        BENE11017   CLM31237   2008-12-25  2009-01-08  PRV54750
# 2        BENE11026   CLM78930   2009-12-09  2009-12-13  PRV53758
# 3        BENE11031   CLM56810   2009-06-23  2009-07-06  PRV55825
# 4        BENE11085   CLM34625   2009-01-20  2009-01-31  PRV52338
# 5        BENE11090   CLM56552   2009-06-21  2009-06-22  PRV55544
# 6        BENE11099   CLM52386   2009-05-23  2009-05-26  PRV53275
# 7        BENE11127   CLM55284   2009-06-12  2009-06-23  PRV54989
# 8        BENE11176   CLM55569   2009-06-14  2009-06-14  PRV57214
# 9        BENE11218   CLM65115   2009-08-24  2009-08-31  PRV52117
# 10       BENE11221   CLM44395   2009-03-28  2009-04-01  PRV55190
# 11       BENE11260   CLM55285   2009-06-12  2009-06-15  PRV54948
# 12       BENE11298   CLM40803   2009-03-02  2009-03-04  PRV54853
# ...

# %%
test_df2=pd.merge(test_df1,test_ben)
test_df2
# Out:
#             BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0        BENE11014   CLM67387   2009-09-09  2009-09-16  PRV57070
# 1        BENE11014  CLM731858   2009-12-16  2009-12-16  PRV56558
# 2        BENE11017   CLM31237   2008-12-25  2009-01-08  PRV54750
# 3        BENE11026   CLM78930   2009-12-09  2009-12-13  PRV53758
# 4        BENE11031   CLM56810   2009-06-23  2009-07-06  PRV55825
# 5        BENE11085   CLM34625   2009-01-20  2009-01-31  PRV52338
# 6        BENE11090   CLM56552   2009-06-21  2009-06-22  PRV55544
# 7        BENE11090  CLM462561   2009-07-10  2009-07-10  PRV55476
# 8        BENE11099   CLM52386   2009-05-23  2009-05-26  PRV53275
# 9        BENE11127   CLM55284   2009-06-12  2009-06-23  PRV54989
# 10       BENE11176   CLM55569   2009-06-14  2009-06-14  PRV57214
# 11       BENE11176  CLM211035   2009-02-23  2009-02-23  PRV57214
# 12       BENE11176  CLM400398   2009-06-06  2009-06-06  PRV57214
# ...

# %%
test_df3=pd.merge(test_df2,test)
test_df3
# Out:
#             BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0        BENE11014   CLM67387   2009-09-09  2009-09-16  PRV57070
# 1        BENE23826   CLM56697   2009-06-22  2009-06-24  PRV57070
# 2        BENE24014   CLM63574   2009-08-12  2009-08-18  PRV57070
# 3        BENE41847   CLM59473   2009-07-13  2009-07-21  PRV57070
# 4        BENE74857   CLM54585   2009-06-07  2009-06-17  PRV57070
# 5        BENE83571   CLM41887   2009-03-09  2009-03-11  PRV57070
# 6        BENE85470   CLM48054   2009-04-22  2009-04-26  PRV57070
# 7       BENE106384   CLM50294   2009-05-08  2009-05-10  PRV57070
# 8       BENE117905   CLM62092   2009-08-01  2009-08-02  PRV57070
# 9       BENE139963   CLM60653   2009-07-21  2009-07-21  PRV57070
# 10      BENE146484   CLM70736   2009-10-04  2009-10-11  PRV57070
# 11      BENE146539   CLM77962   2009-11-30  2009-12-08  PRV57070
# 12       BENE11014  CLM731858   2009-12-16  2009-12-16  PRV56558
# ...

# %%
train_df3.shape
# Out:
# (558211, 55)

# %%
test_df3.shape
# Out:
# (135392, 54)

# %%
train_df3.columns
# Out:
# Index(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
#        'OtherPhysician', 'AdmissionDt', 'ClmAdmitDiagnosisCode',
#        'DeductibleAmtPaid', 'DischargeDt', 'DiagnosisGroupCode',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
#        'ClmProcedureCode_6', 'DOB', 'DOD', 'Gender', 'Race',
#        'RenalDiseaseIndicator', 'State', 'County', 'NoOfMonths_PartACov',
#        'NoOfMonths_PartBCov', 'ChronicCond_Alzheimer',
#        'ChronicCond_Heartfailure', 'ChronicCond_KidneyDisease',
#        'ChronicCond_Cancer', 'ChronicCond_ObstrPulmonary',
# ...

# %%
test_df3.columns
# Out:
# Index(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
#        'OtherPhysician', 'AdmissionDt', 'ClmAdmitDiagnosisCode',
#        'DeductibleAmtPaid', 'DischargeDt', 'DiagnosisGroupCode',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
#        'ClmProcedureCode_6', 'DOB', 'DOD', 'Gender', 'Race',
#        'RenalDiseaseIndicator', 'State', 'County', 'NoOfMonths_PartACov',
#        'NoOfMonths_PartBCov', 'ChronicCond_Alzheimer',
#        'ChronicCond_Heartfailure', 'ChronicCond_KidneyDisease',
#        'ChronicCond_Cancer', 'ChronicCond_ObstrPulmonary',
# ...

# %%
train_df3.isnull().sum()
# Out:
# BeneID                                  0
# ClaimID                                 0
# ClaimStartDt                            0
# ClaimEndDt                              0
# Provider                                0
# InscClaimAmtReimbursed                  0
# AttendingPhysician                   1508
# OperatingPhysician                 443764
# OtherPhysician                     358475
# AdmissionDt                        517737
# ClmAdmitDiagnosisCode              412312
# DeductibleAmtPaid                     899
# DischargeDt                        517737
# DiagnosisGroupCode                 517737
# ClmDiagnosisCode_1                  10453
# ClmDiagnosisCode_2                 195606
# ClmDiagnosisCode_3                 315156
# ClmDiagnosisCode_4                 393675
# ClmDiagnosisCode_5                 446287
# ClmDiagnosisCode_6                 473819
# ClmDiagnosisCode_7                 492034
# ClmDiagnosisCode_8                 504767
# ...

# %%
test_df3.isnull().sum()
# Out:
# BeneID                                  0
# ClaimID                                 0
# ClaimStartDt                            0
# ClaimEndDt                              0
# Provider                                0
# InscClaimAmtReimbursed                  0
# AttendingPhysician                    347
# OperatingPhysician                 108199
# OtherPhysician                      86760
# AdmissionDt                        125841
# ClmAdmitDiagnosisCode              100036
# DeductibleAmtPaid                     196
# DischargeDt                        125841
# DiagnosisGroupCode                 125841
# ClmDiagnosisCode_1                   2578
# ClmDiagnosisCode_2                  47785
# ClmDiagnosisCode_3                  76744
# ClmDiagnosisCode_4                  95775
# ClmDiagnosisCode_5                 108594
# ClmDiagnosisCode_6                 115232
# ClmDiagnosisCode_7                 119607
# ClmDiagnosisCode_8                 122670
# ...

# %%
train_df3.dtypes
# Out:
# BeneID                              object
# ClaimID                             object
# ClaimStartDt                        object
# ClaimEndDt                          object
# Provider                            object
# InscClaimAmtReimbursed               int64
# AttendingPhysician                  object
# OperatingPhysician                  object
# OtherPhysician                      object
# AdmissionDt                         object
# ClmAdmitDiagnosisCode               object
# DeductibleAmtPaid                  float64
# DischargeDt                         object
# DiagnosisGroupCode                  object
# ClmDiagnosisCode_1                  object
# ClmDiagnosisCode_2                  object
# ClmDiagnosisCode_3                  object
# ClmDiagnosisCode_4                  object
# ClmDiagnosisCode_5                  object
# ClmDiagnosisCode_6                  object
# ClmDiagnosisCode_7                  object
# ClmDiagnosisCode_8                  object
# ...

# %%
test_df3.dtypes
# Out:
# BeneID                              object
# ClaimID                             object
# ClaimStartDt                        object
# ClaimEndDt                          object
# Provider                            object
# InscClaimAmtReimbursed               int64
# AttendingPhysician                  object
# OperatingPhysician                  object
# OtherPhysician                      object
# AdmissionDt                         object
# ClmAdmitDiagnosisCode               object
# DeductibleAmtPaid                  float64
# DischargeDt                         object
# DiagnosisGroupCode                  object
# ClmDiagnosisCode_1                  object
# ClmDiagnosisCode_2                  object
# ClmDiagnosisCode_3                  object
# ClmDiagnosisCode_4                  object
# ClmDiagnosisCode_5                  object
# ClmDiagnosisCode_6                  object
# ClmDiagnosisCode_7                  object
# ClmDiagnosisCode_8                  object
# ...

# %%
train_df3.describe()
# Out:
#        InscClaimAmtReimbursed  DeductibleAmtPaid  ClmProcedureCode_1  \
# count           558211.000000      557312.000000        23310.000000
# mean               997.012133          78.421085         5896.154612
# std               3821.534891         274.016812         3050.489933
# min                  0.000000           0.000000           11.000000
# 25%                 40.000000           0.000000         3848.000000
# 50%                 80.000000           0.000000         5363.000000
# 75%                300.000000           0.000000         8669.000000
# max             125000.000000        1068.000000         9999.000000
#
#        ClmProcedureCode_2  ClmProcedureCode_3  ClmProcedureCode_4  \
# count         5490.000000          969.000000          118.000000
# mean          4106.358106         4221.123839         4070.262712
# std           2031.640878         2281.849885         2037.626990
# min             42.000000           42.000000           42.000000
# ...

# %%
test_df3.describe()
# Out:
#        InscClaimAmtReimbursed  DeductibleAmtPaid  ClmProcedureCode_1  \
# count           135392.000000      135196.000000         5467.000000
# mean               981.307906          76.499194         5905.430766
# std               3788.177532         270.779562         3057.976988
# min                  0.000000           0.000000           14.000000
# 25%                 40.000000           0.000000         3891.000000
# 50%                 80.000000           0.000000         5369.000000
# 75%                300.000000           0.000000         8741.000000
# max             125000.000000        1068.000000         9999.000000
#
#        ClmProcedureCode_2  ClmProcedureCode_3  ClmProcedureCode_4  \
# count         1263.000000          225.000000           29.000000
# mean          4138.790182         4182.213333         4509.931034
# std           2042.016095         2165.057828         2571.379659
# min             42.000000          185.000000          260.000000
# ...

# %%
# converting different date formats into single date format
train_df3['AdmissionDt'] = pd.to_datetime(train_df3['AdmissionDt'] , format = '%Y-%m-%d')
train_df3['DischargeDt'] = pd.to_datetime(train_df3['DischargeDt'],format = '%Y-%m-%d')
train_df3['ClaimStartDt'] = pd.to_datetime(train_df3['ClaimStartDt'],format = '%Y-%m-%d')
train_df3['ClaimEndDt'] = pd.to_datetime(train_df3['ClaimEndDt'],format = '%Y-%m-%d')
train_df3['DOB'] = pd.to_datetime(train_df3['DOB'],format = '%Y-%m-%d')
train_df3['DOD'] = pd.to_datetime(train_df3['DOD'],format = '%Y-%m-%d')

# %%
#Creating a new column 'Age' by subtracting ClaimStartDt and DOB columns
train_df3['Age'] = (train_df3.ClaimStartDt - train_df3.DOB).astype('<m8[Y]')
train_df3.head(5)
# Out:
#       BeneID    ClaimID ClaimStartDt ClaimEndDt  Provider  \
# 0  BENE11001   CLM46614   2009-04-12 2009-04-18  PRV55912
# 1  BENE16973  CLM565430   2009-09-06 2009-09-06  PRV55912
# 2  BENE17521   CLM34721   2009-01-20 2009-02-01  PRV55912
# 3  BENE21718   CLM72336   2009-10-17 2009-11-04  PRV55912
# 4  BENE22934   CLM73394   2009-10-25 2009-10-29  PRV55912
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                      50          PHY365867          PHY327147
# 2                   19000          PHY349293          PHY370861
# 3                   17000          PHY334706          PHY334706
# 4                   13000          PHY390614          PHY323689
#
#   OtherPhysician AdmissionDt  ...  ChronicCond_IschemicHeart  \
# 0            NaN  2009-04-12  ...                          1
# 1            NaN         NaT  ...                          1
# ...

# %%
#Creating a new column 'NoOfClaimDays' by subtracting ClaimStartDt and ClaimEndDt columns
train_df3['NoOfClaimDays'] = (train_df3.ClaimEndDt - train_df3.ClaimStartDt).dt.days
train_df3.head(5)
# Out:
#       BeneID    ClaimID ClaimStartDt ClaimEndDt  Provider  \
# 0  BENE11001   CLM46614   2009-04-12 2009-04-18  PRV55912
# 1  BENE16973  CLM565430   2009-09-06 2009-09-06  PRV55912
# 2  BENE17521   CLM34721   2009-01-20 2009-02-01  PRV55912
# 3  BENE21718   CLM72336   2009-10-17 2009-11-04  PRV55912
# 4  BENE22934   CLM73394   2009-10-25 2009-10-29  PRV55912
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                      50          PHY365867          PHY327147
# 2                   19000          PHY349293          PHY370861
# 3                   17000          PHY334706          PHY334706
# 4                   13000          PHY390614          PHY323689
#
#   OtherPhysician AdmissionDt      ...      ChronicCond_Osteoporasis  \
# 0            NaN  2009-04-12      ...                             2
# 1            NaN         NaT      ...                             2
# ...

# %%
#Creating a new column 'NoOfClaimDays' by subtracting ClaimStartDt and ClaimEndDt columns
train_df3['NoOfDaysAdmitted'] = (train_df3.DischargeDt - train_df3.AdmissionDt).dt.days

# %%
train_df3.head(5)
# Out:
#       BeneID    ClaimID ClaimStartDt ClaimEndDt  Provider  \
# 0  BENE11001   CLM46614   2009-04-12 2009-04-18  PRV55912
# 1  BENE16973  CLM565430   2009-09-06 2009-09-06  PRV55912
# 2  BENE17521   CLM34721   2009-01-20 2009-02-01  PRV55912
# 3  BENE21718   CLM72336   2009-10-17 2009-11-04  PRV55912
# 4  BENE22934   CLM73394   2009-10-25 2009-10-29  PRV55912
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                      50          PHY365867          PHY327147
# 2                   19000          PHY349293          PHY370861
# 3                   17000          PHY334706          PHY334706
# 4                   13000          PHY390614          PHY323689
#
#   OtherPhysician AdmissionDt       ...        ChronicCond_rheumatoidarthritis  \
# 0            NaN  2009-04-12       ...                                      1
# ...

# %%
train_df3.drop(["AdmissionDt","DischargeDt","ClaimStartDt","ClaimEndDt","DOB","DOD","AttendingPhysician","ClaimID","BeneID","Provider","ClmDiagnosisCode_1","ClmDiagnosisCode_2","ClmDiagnosisCode_3"],axis=1,inplace=True)

# %%
Final_DF=train_df3[train_df3.columns[train_df3.isnull().mean()<0.6]]
Final_DF
# Out:
#         InscClaimAmtReimbursed  DeductibleAmtPaid  Gender  Race  \
# 0                        26000             1068.0       1     1
# 1                           50                0.0       1     1
# 2                        19000             1068.0       2     1
# 3                        17000             1068.0       1     1
# 4                        13000             1068.0       2     1
# 5                         3000             1068.0       2     2
# 6                           20                0.0       1     2
# 7                        10000             1068.0       1     1
# 8                        18000             1068.0       2     1
# 9                        13000             1068.0       2     2
# 10                        7000             1068.0       2     2
# 11                        7000             1068.0       2     2
# 12                        6000             1068.0       2     2
# 13                        7000             1068.0       1     1
# ...

# %%
Final_DF.columns
# Out:
# Index(['InscClaimAmtReimbursed', 'DeductibleAmtPaid', 'Gender', 'Race',
#        'RenalDiseaseIndicator', 'State', 'County', 'NoOfMonths_PartACov',
#        'NoOfMonths_PartBCov', 'ChronicCond_Alzheimer',
#        'ChronicCond_Heartfailure', 'ChronicCond_KidneyDisease',
#        'ChronicCond_Cancer', 'ChronicCond_ObstrPulmonary',
#        'ChronicCond_Depression', 'ChronicCond_Diabetes',
#        'ChronicCond_IschemicHeart', 'ChronicCond_Osteoporasis',
#        'ChronicCond_rheumatoidarthritis', 'ChronicCond_stroke',
#        'IPAnnualReimbursementAmt', 'IPAnnualDeductibleAmt',
#        'OPAnnualReimbursementAmt', 'OPAnnualDeductibleAmt', 'PotentialFraud',
#        'Age', 'NoOfClaimDays'],
#       dtype='object')

# %%
Final_DF["RenalDiseaseIndicator"]=pd.Categorical(Final_DF["RenalDiseaseIndicator"])
# Out:
# E:\PYTHON\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Final_DF['DeductibleAmtPaid'].fillna((Final_DF['DeductibleAmtPaid'].mean()), inplace=True)
# Out:
# E:\PYTHON\lib\site-packages\pandas\core\generic.py:5430: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()

# %%
Final_DF["RenalDiseaseIndicator"]=le.fit_transform(Final_DF["RenalDiseaseIndicator"])
# Out:
# E:\PYTHON\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Final_DF.isnull().sum()
# Out:
# InscClaimAmtReimbursed             0
# DeductibleAmtPaid                  0
# Gender                             0
# Race                               0
# RenalDiseaseIndicator              0
# State                              0
# County                             0
# NoOfMonths_PartACov                0
# NoOfMonths_PartBCov                0
# ChronicCond_Alzheimer              0
# ChronicCond_Heartfailure           0
# ChronicCond_KidneyDisease          0
# ChronicCond_Cancer                 0
# ChronicCond_ObstrPulmonary         0
# ChronicCond_Depression             0
# ChronicCond_Diabetes               0
# ChronicCond_IschemicHeart          0
# ChronicCond_Osteoporasis           0
# ChronicCond_rheumatoidarthritis    0
# ChronicCond_stroke                 0
# IPAnnualReimbursementAmt           0
# IPAnnualDeductibleAmt              0
# OPAnnualReimbursementAmt           0
# OPAnnualDeductibleAmt              0
# PotentialFraud                     0
# ...

# %%
# converting different date formats into single date format
test_df3['AdmissionDt'] = pd.to_datetime(test_df3['AdmissionDt'] , format = '%Y-%m-%d')
test_df3['DischargeDt'] = pd.to_datetime(test_df3['DischargeDt'],format = '%Y-%m-%d')
test_df3['ClaimStartDt'] = pd.to_datetime(test_df3['ClaimStartDt'],format = '%Y-%m-%d')
test_df3['ClaimEndDt'] = pd.to_datetime(test_df3['ClaimEndDt'],format = '%Y-%m-%d')
test_df3['DOB'] = pd.to_datetime(test_df3['DOB'],format = '%Y-%m-%d')
test_df3['DOD'] = pd.to_datetime(test_df3['DOD'],format = '%Y-%m-%d')

# %%
#Creating a new column 'Age' by subtracting ClaimStartDt and DOB columns
test_df3['Age'] = (test_df3.ClaimStartDt - test_df3.DOB).astype('<m8[Y]')
test_df3.head(5)
# Out:
#       BeneID   ClaimID ClaimStartDt ClaimEndDt  Provider  \
# 0  BENE11014  CLM67387   2009-09-09 2009-09-16  PRV57070
# 1  BENE23826  CLM56697   2009-06-22 2009-06-24  PRV57070
# 2  BENE24014  CLM63574   2009-08-12 2009-08-18  PRV57070
# 3  BENE41847  CLM59473   2009-07-13 2009-07-21  PRV57070
# 4  BENE74857  CLM54585   2009-06-07 2009-06-17  PRV57070
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                    9000          PHY317786          PHY427017
# 1                    3000          PHY427017                NaN
# 2                    7000          PHY426001          PHY351953
# 3                    5000          PHY426001          PHY351953
# 4                    9000          PHY351953          PHY351953
#
#   OtherPhysician AdmissionDt  ...  ChronicCond_Diabetes  \
# 0            NaN  2009-09-09  ...                     2
# 1      PHY351953  2009-06-22  ...                     1
# 2            NaN  2009-08-12  ...                     2
# ...

# %%
#Creating a new column 'NoOfClaimDays' by subtracting ClaimStartDt and ClaimEndDt columns
test_df3['NoOfClaimDays'] = (test_df3.ClaimEndDt - test_df3.ClaimStartDt).dt.days
test_df3.head(5)
# Out:
#       BeneID   ClaimID ClaimStartDt ClaimEndDt  Provider  \
# 0  BENE11014  CLM67387   2009-09-09 2009-09-16  PRV57070
# 1  BENE23826  CLM56697   2009-06-22 2009-06-24  PRV57070
# 2  BENE24014  CLM63574   2009-08-12 2009-08-18  PRV57070
# 3  BENE41847  CLM59473   2009-07-13 2009-07-21  PRV57070
# 4  BENE74857  CLM54585   2009-06-07 2009-06-17  PRV57070
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                    9000          PHY317786          PHY427017
# 1                    3000          PHY427017                NaN
# 2                    7000          PHY426001          PHY351953
# 3                    5000          PHY426001          PHY351953
# 4                    9000          PHY351953          PHY351953
#
#   OtherPhysician AdmissionDt      ...      ChronicCond_IschemicHeart  \
# 0            NaN  2009-09-09      ...                              1
# 1      PHY351953  2009-06-22      ...                              1
# ...

# %%
#Creating a new column 'NoOfClaimDays' by subtracting ClaimStartDt and ClaimEndDt columns
test_df3['NoOfDaysAdmitted'] = (test_df3.DischargeDt - test_df3.AdmissionDt).dt.days

# %%
test_df3["RenalDiseaseIndicator"]=pd.Categorical(test_df3["RenalDiseaseIndicator"])

# %%
test_df3["Provider"]=pd.Categorical(test_df3["Provider"])

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()

# %%
test_df3["RenalDiseaseIndicator"]=le.fit_transform(test_df3["RenalDiseaseIndicator"])

# %%
Test_DF=test_df3[test_df3.columns[test_df3.isnull().mean()<0.6]]
Test_DF
# Out:
#             BeneID    ClaimID ClaimStartDt ClaimEndDt  Provider  \
# 0        BENE11014   CLM67387   2009-09-09 2009-09-16  PRV57070
# 1        BENE23826   CLM56697   2009-06-22 2009-06-24  PRV57070
# 2        BENE24014   CLM63574   2009-08-12 2009-08-18  PRV57070
# 3        BENE41847   CLM59473   2009-07-13 2009-07-21  PRV57070
# 4        BENE74857   CLM54585   2009-06-07 2009-06-17  PRV57070
# 5        BENE83571   CLM41887   2009-03-09 2009-03-11  PRV57070
# 6        BENE85470   CLM48054   2009-04-22 2009-04-26  PRV57070
# 7       BENE106384   CLM50294   2009-05-08 2009-05-10  PRV57070
# 8       BENE117905   CLM62092   2009-08-01 2009-08-02  PRV57070
# 9       BENE139963   CLM60653   2009-07-21 2009-07-21  PRV57070
# 10      BENE146484   CLM70736   2009-10-04 2009-10-11  PRV57070
# 11      BENE146539   CLM77962   2009-11-30 2009-12-08  PRV57070
# 12       BENE11014  CLM731858   2009-12-16 2009-12-16  PRV56558
# 13       BENE12334  CLM730366   2009-12-15 2009-12-15  PRV56558
# ...

# %%
Test_DF.columns
# Out:
# Index(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AttendingPhysician', 'DeductibleAmtPaid',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3', 'DOB',
#        'Gender', 'Race', 'RenalDiseaseIndicator', 'State', 'County',
#        'NoOfMonths_PartACov', 'NoOfMonths_PartBCov', 'ChronicCond_Alzheimer',
#        'ChronicCond_Heartfailure', 'ChronicCond_KidneyDisease',
#        'ChronicCond_Cancer', 'ChronicCond_ObstrPulmonary',
#        'ChronicCond_Depression', 'ChronicCond_Diabetes',
#        'ChronicCond_IschemicHeart', 'ChronicCond_Osteoporasis',
#        'ChronicCond_rheumatoidarthritis', 'ChronicCond_stroke',
#        'IPAnnualReimbursementAmt', 'IPAnnualDeductibleAmt',
#        'OPAnnualReimbursementAmt', 'OPAnnualDeductibleAmt', 'Age',
#        'NoOfClaimDays'],
#       dtype='object')

# %%
Test_DF['DeductibleAmtPaid'].fillna((Test_DF['DeductibleAmtPaid'].mean()), inplace=True)
# Out:
# E:\PYTHON\lib\site-packages\pandas\core\generic.py:5430: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
Test_DF.drop(["ClaimStartDt","ClaimEndDt","DOB","AttendingPhysician","ClaimID","BeneID","Provider","ClmDiagnosisCode_1","ClmDiagnosisCode_2","ClmDiagnosisCode_3"],axis=1,inplace=True)
# Out:
# E:\PYTHON\lib\site-packages\pandas\core\frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
Test_DF.shape
# Out:
# (135392, 26)

# %%
Test_DF.isnull().sum()
# Out:
# InscClaimAmtReimbursed             0
# DeductibleAmtPaid                  0
# Gender                             0
# Race                               0
# RenalDiseaseIndicator              0
# State                              0
# County                             0
# NoOfMonths_PartACov                0
# NoOfMonths_PartBCov                0
# ChronicCond_Alzheimer              0
# ChronicCond_Heartfailure           0
# ChronicCond_KidneyDisease          0
# ChronicCond_Cancer                 0
# ChronicCond_ObstrPulmonary         0
# ChronicCond_Depression             0
# ChronicCond_Diabetes               0
# ChronicCond_IschemicHeart          0
# ChronicCond_Osteoporasis           0
# ChronicCond_rheumatoidarthritis    0
# ChronicCond_stroke                 0
# IPAnnualReimbursementAmt           0
# IPAnnualDeductibleAmt              0
# OPAnnualReimbursementAmt           0
# OPAnnualDeductibleAmt              0
# Age                                0
# ...

# %%
Final_DF.head()
# Out:
#    InscClaimAmtReimbursed  DeductibleAmtPaid  Gender  Race  \
# 0                   26000             1068.0       1     1
# 1                      50                0.0       1     1
# 2                   19000             1068.0       2     1
# 3                   17000             1068.0       1     1
# 4                   13000             1068.0       2     1
#
#    RenalDiseaseIndicator  State  County  NoOfMonths_PartACov  \
# 0                      0     39     230                   12
# 1                      0     39     310                   12
# 2                      0     39     230                   12
# 3                      0     39     600                   12
# 4                      0     39     280                   12
#
#    NoOfMonths_PartBCov  ChronicCond_Alzheimer      ...        \
# 0                   12                      1      ...
# 1                   12                      1      ...
# 2                   12                      1      ...
# ...

# %%
x = Final_DF.drop(["PotentialFraud"],axis=1)

# %%
y = Final_DF.drop([ 'NoOfClaimDays' , 'Age',
       'InscClaimAmtReimbursed','DeductibleAmtPaid', 'Gender', 'Race',
       'RenalDiseaseIndicator', 'State', 'County', 'NoOfMonths_PartACov',
       'NoOfMonths_PartBCov', 'ChronicCond_Alzheimer',
       'ChronicCond_Heartfailure', 'ChronicCond_KidneyDisease',
       'ChronicCond_Cancer', 'ChronicCond_ObstrPulmonary',
       'ChronicCond_Depression', 'ChronicCond_Diabetes',
       'ChronicCond_IschemicHeart', 'ChronicCond_Osteoporasis',
       'ChronicCond_rheumatoidarthritis', 'ChronicCond_stroke',
       'IPAnnualReimbursementAmt', 'IPAnnualDeductibleAmt',
       'OPAnnualReimbursementAmt', 'OPAnnualDeductibleAmt'],axis  = 1)

# %%
from sklearn.cross_validation import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
# Out:
# E:\PYTHON\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
X_train,X_validation,y_train,y_validation = train_test_split(x, y, test_size=0.2, random_state=100)

# %%
X_train.shape
# Out:
# (446568, 26)

# %%
y_train.shape
# Out:
# (446568, 1)

# %%
X_validation.shape
# Out:
# (111643, 26)

# %%
y_validation.shape
# Out:
# (111643, 1)

# %%
X_train['RenalDiseaseIndicator']=X_train['RenalDiseaseIndicator'].astype('float')
# Out:
# E:\PYTHON\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X_validation['RenalDiseaseIndicator']=X_validation['RenalDiseaseIndicator'].astype('float')
# Out:
# E:\PYTHON\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Test_DF['RenalDiseaseIndicator']=Test_DF['RenalDiseaseIndicator'].astype('float')
# Out:
# E:\PYTHON\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
# Out:
# E:\PYTHON\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
train_pred = logreg.predict(X_train)

# %%
accuracy_score(train_pred,y_train)
# Out:
# 0.6295211479550706

# %%
y_pred = logreg.predict(X_validation)

# %%
accuracy_score(y_pred,y_validation)
# Out:
# 0.6308411633510386

# %%
print(classification_report(y_validation,y_pred))
# Out:
#              precision    recall  f1-score   support
#
#          No       0.64      0.95      0.76     69304
#         Yes       0.57      0.11      0.18     42339
#
# avg / total       0.61      0.63      0.54    111643

# %%
test_preds = logreg.predict(Test_DF)

# %%
Logreg_prediction=test_preds.tolist()

# %%
test_df3["PotentialFraud"] = Logreg_prediction

# %%
Logreg_csv=test_df3[['Provider','PotentialFraud']]

# %%
Logreg_csv=Logreg_csv.drop_duplicates()

# %%
Logreg_csv=Logreg_csv[~Logreg_csv.Provider.duplicated(keep='first')]

# %%
Logreg_csv['Provider'].nunique()
# Out:
# 1353

# %%
Logreg_csv.shape
# Out:
# (1353, 2)

# %%
Logreg_csv.to_csv("LogregTestPredictions2.csv",index=False)

# %%
Logreg_csv.head(5)
# Out:
#       Provider PotentialFraud
# 0     PRV57070            Yes
# 12    PRV56558             No
# 1160  PRV54750            Yes
# 1198  PRV53758            Yes
# 1381  PRV55825            Yes

# %% [markdown]
# # Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DT=DecisionTreeClassifier(max_depth=3)

# %%
model=DT.fit(X_train,y_train)

# %%
pred=model.predict(X_train)

# %%
accuracy_score(y_pred=pred,y_true=y_train)
# Out:
# 0.6410468282545996

# %%
pred_val=model.predict(X_validation)

# %%
accuracy_score(y_pred=pred_val,y_true=y_validation)
# Out:
# 0.6427362217066901

# %%
print(classification_report(y_validation,pred_val))
# Out:
#              precision    recall  f1-score   support
#
#          No       0.67      0.83      0.74     69304
#         Yes       0.55      0.33      0.41     42339
#
# avg / total       0.62      0.64      0.62    111643

# %%
test = model.predict(Test_DF)

# %%
test_prediction=test.tolist()

# %%
test_df3["PotentialFraud"] = test_prediction

# %%
DTcsv=test_df3[['Provider','PotentialFraud']]

# %%
DTcsv=DTcsv.drop_duplicates()

# %%
DTcsv=DTcsv[~DTcsv.Provider.duplicated(keep='first')]

# %%
DTcsv['Provider'].nunique()
# Out:
# 1353

# %%
DTcsv.shape
# Out:
# (1353, 2)

# %%
DTcsv.to_csv("DtTestPredictions1.csv",index=False)

# %%
DTcsv.head(5)
# Out:
#       Provider PotentialFraud
# 0     PRV57070            Yes
# 12    PRV56558             No
# 1160  PRV54750            Yes
# 1198  PRV53758            Yes
# 1381  PRV55825            Yes

# %% [markdown]
# # ADABOOST

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
# Out:
# E:\PYTHON\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
Adaboost_model = AdaBoostClassifier(
    DecisionTreeClassifier(max_depth=2),
    n_estimators = 50,
    learning_rate = 1
)

# %%
# %time Adaboost_model.fit(X_train, y_train)
# Out:
# E:\PYTHON\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Wall time: 7min 5s
# AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=2,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1, n_estimators=50, random_state=None)

# %%
train_pred = Adaboost_model.predict(X_train)

# %%
accuracy_score(train_pred,y_train)
# Out:
# 0.6915632109779474

# %%
validation_pred = Adaboost_model.predict(X_validation)

# %%
accuracy_score(validation_pred,y_validation)
# Out:
# 0.6918749944017986

# %%
print(classification_report(y_validation,validation_pred))
# Out:
#              precision    recall  f1-score   support
#
#          No       0.71      0.86      0.78     69304
#         Yes       0.64      0.42      0.51     42339
#
# avg / total       0.68      0.69      0.67    111643

# %%
test_preds = Adaboost_model.predict(Test_DF)

# %%
Adaboost_prediction=test_preds.tolist()

# %%
test_df3["PotentialFraud"] = Adaboost_prediction

# %%
Adaboost_csv=test_df3[['Provider','PotentialFraud']]

# %%
Adaboost_csv=Adaboost_csv.drop_duplicates()

# %%
Adaboost_csv=Adaboost_csv[~Adaboost_csv.Provider.duplicated(keep='first')]

# %%
Adaboost_csv['Provider'].nunique()
# Out:
# 1353

# %%
Adaboost_csv.shape
# Out:
# (1353, 2)

# %%
Adaboost_csv.to_csv("AdaboostTestPredictions.csv",index=False)

# %%
Adaboost_csv.head(5)
# Out:
#       Provider PotentialFraud
# 0     PRV57070            Yes
# 12    PRV56558            Yes
# 1160  PRV54750            Yes
# 1198  PRV53758            Yes
# 1381  PRV55825             No

# %% [markdown]
# # RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier
regressor = RandomForestClassifier(n_estimators=20)  
regressor.fit(X_train, y_train)
# Out:
# E:\PYTHON\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=20, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
preds=regressor.predict(X_train)

# %%
accuracy_score(preds,y_train)
# Out:
# 0.9781511438347575

# %%
y_pred = regressor.predict(X_validation)

# %%
accuracy_score(y_validation,y_pred)
# Out:
# 0.7201257579964709

# %%
print(classification_report(y_validation,y_pred))
# Out:
#              precision    recall  f1-score   support
#
#          No       0.76      0.81      0.78     69304
#         Yes       0.65      0.58      0.61     42339
#
# avg / total       0.72      0.72      0.72    111643

# %%
test_preds = regressor.predict(Test_DF)

# %%
test_predicts=test_preds.tolist()

# %%
test_df3["PotentialFraud"] = test_predicts

# %%
RFcsv=test_df3[['Provider','PotentialFraud']]

# %%
RFcsv=RFcsv.drop_duplicates()

# %%
RFcsv=RFcsv[~RFcsv.Provider.duplicated(keep='first')]

# %%
RFcsv['Provider'].nunique()
# Out:
# 1353

# %%
RFcsv.shape
# Out:
# (1353, 2)

# %%
RFcsv.to_csv("RFTestPredictions1.csv",index=False)

# %%
RFcsv.head(5)
# Out:
#       Provider PotentialFraud
# 0     PRV57070             No
# 12    PRV56558             No
# 1160  PRV54750             No
# 1198  PRV53758             No
# 1381  PRV55825             No

# %% [markdown]
# # XGBoost

# %%
from xgboost import XGBClassifier
xgb_model = XGBClassifier(n_estimators=250, learning_rate=0.1, max_depth=7, min_samples_leaf=20)

# %%
xgb_model.fit(X_train, y_train)
# Out:
# E:\PYTHON\lib\site-packages\sklearn\preprocessing\label.py:95: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# E:\PYTHON\lib\site-packages\sklearn\preprocessing\label.py:128: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=7, min_child_weight=1, min_samples_leaf=20, missing=None,
#        n_estimators=250, n_jobs=1, nthread=None,
#        objective='binary:logistic', random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#        subsample=1)

# %%
train_pred = xgb_model.predict(X_train)
# Out:
# E:\PYTHON\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
accuracy_score(train_pred,y_train)
# Out:
# 0.7795207000949463

# %%
validation_pred = xgb_model.predict(X_validation)
# Out:
# E:\PYTHON\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
accuracy_score(validation_pred,y_validation)
# Out:
# 0.7711634406098009

# %%
print(classification_report(y_validation,validation_pred))
# Out:
#              precision    recall  f1-score   support
#
#          No       0.78      0.87      0.83     69304
#         Yes       0.75      0.60      0.67     42339
#
# avg / total       0.77      0.77      0.77    111643

# %%
test_preds = xgb_model.predict(Test_DF)
# Out:
# E:\PYTHON\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
test_predicts=test_preds.tolist()

# %%
test_df3["PotentialFraud"] = test_predicts

# %%
XGBcsv=test_df3[['Provider','PotentialFraud']]

# %%
XGBcsv=XGBcsv.drop_duplicates()

# %%
XGBcsv=XGBcsv[~XGBcsv.Provider.duplicated(keep='first')]

# %%
XGBcsv['Provider'].nunique()
# Out:
# 1353

# %%
XGBcsv.shape
# Out:
# (1353, 2)

# %%
XGBcsv.to_csv("XGBTestPredictions1.csv",index=False)

# %%
XGBcsv.head()
# Out:
#       Provider PotentialFraud
# 0     PRV57070             No
# 12    PRV56558             No
# 1160  PRV54750            Yes
# 1198  PRV53758            Yes
# 1381  PRV55825             No

# %% [markdown]
# # Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
GBM_model = GradientBoostingClassifier(n_estimators=50,
                                       learning_rate=0.3,
                                       subsample=0.8)

# %%
# %time GBM_model.fit(X_train, y_train)
# Out:
# E:\PYTHON\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Wall time: 2min 32s
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.3, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=50,
#               presort='auto', random_state=None, subsample=0.8, verbose=0,
#               warm_start=False)

# %%
train_pred = GBM_model.predict(X_train)

# %%
accuracy_score(train_pred,y_train)
# Out:
# 0.7074353737840597

# %%
validation_pred = GBM_model.predict(X_validation)

# %%
accuracy_score(y_validation,validation_pred)
# Out:
# 0.7075947439606604

# %%
print(classification_report(y_validation,validation_pred))
# Out:
#              precision    recall  f1-score   support
#
#          No       0.72      0.87      0.79     69304
#         Yes       0.67      0.45      0.54     42339
#
# avg / total       0.70      0.71      0.69    111643

# %%
test_preds = GBM_model.predict(Test_DF)

# %%
GBM_prediction=test_preds.tolist()

# %%
test_df3["PotentialFraud"] = GBM_prediction

# %%
GBM_csv=test_df3[['Provider','PotentialFraud']]

# %%
GBM_csv=GBM_csv.drop_duplicates()

# %%
GBM_csv=GBM_csv[~GBM_csv.Provider.duplicated(keep='first')]

# %%
GBM_csv['Provider'].nunique()
# Out:
# 1353

# %%
GBM_csv.shape
# Out:
# (1353, 2)

# %%
GBM_csv.to_csv("GBMTestPredictions1.csv",index=False)

# %%
GBM_csv.head()
# Out:
#       Provider PotentialFraud
# 0     PRV57070            Yes
# 12    PRV56558             No
# 1160  PRV54750            Yes
# 1198  PRV53758            Yes
# 1381  PRV55825            Yes
